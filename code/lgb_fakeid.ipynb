# %%
import os

# lightgbm的默认线程数是取openmp的默认线程数
os.environ['NUM_OMP_THREADS'] = "4"

import numpy as np
import pandas as pd
from tqdm import tqdm
import time
from contextlib import contextmanager
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
import warnings
from scipy.stats import pearsonr
import seaborn as sns
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',100)

from clf_utils import *

# %%
with timer('load train_feat_df'):
    train_feat_df = pd.read_csv('../input/train_feat_df.csv')
with timer('load test_feat_df'):
    test_feat_df = pd.read_csv('../input/test_feat_df.csv')
# Out:
# [load train_feat_df] done in 3.34 seconds
# [load test_feat_df] done in 1.14 seconds

# %%
train_feat_df = pd.concat([train_feat_df, pd.get_dummies(train_feat_df['设备类型'],prefix='设备类型')],axis=1)
test_feat_df = pd.concat([test_feat_df, pd.get_dummies(test_feat_df['设备类型'],prefix='设备类型')],axis=1)

# %%
feat_df = pd.concat([train_feat_df, test_feat_df],axis=0)

# %%
tmp = feat_df['活塞工作时长'].astype(str)+'#'\
    +feat_df['设备类型'].astype(str)+'#'\
    +feat_df['低压开关'].astype(str)+'#'\
    +feat_df['正泵'].astype(str)
lbl = LabelEncoder()
feat_df['fake_id'] = lbl.fit_transform(tmp)

# %%
train_feat_df = feat_df[:len(train_feat_df)]
test_feat_df = feat_df[len(train_feat_df):]

# %%
col = ['发动机转速','油泵转速','泵送压力','液压油温','流量档位','分配压力','排量电流']

feature_common = ['活塞工作时长','num_samples','低压开关','反泵','fake_id'] +\
    [f'min_{col}' for col in col] +\
    [f'max_{col}' for col in col] +\
    [f'nuni_{col}' for col in col] +\
    [f'mean_{col}' for col in col]

feature_name1 = feature_common + ['设备类型']

feature_name2 = feature_common + ['设备类型_0','设备类型_1','设备类型_2',
                                  '设备类型_3','设备类型_4','设备类型_5','设备类型_6']

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                categorical_feature=['设备类型','fake_id'],
                output_dir='gotcha_fakeid', name='lgb1',
                random_state=1997,
                n_folds=5, split_seed=8888,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=1,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=6)
train_prob = np.load('./gotcha_fakeid/val.lgb1.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb1.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.75183	train's f1: 0.679745	test's auc: 0.697364	test's f1: 0.6411
# [400]	train's auc: 0.803411	train's f1: 0.716941	test's auc: 0.712644	test's f1: 0.650266
# [600]	train's auc: 0.844637	train's f1: 0.75451	test's auc: 0.723478	test's f1: 0.662253
# [800]	train's auc: 0.875455	train's f1: 0.784792	test's auc: 0.731688	test's f1: 0.668442
# [1000]	train's auc: 0.898761	train's f1: 0.809042	test's auc: 0.737813	test's f1: 0.67377
# [1200]	train's auc: 0.916781	train's f1: 0.828081	test's auc: 0.742408	test's f1: 0.675729
# [1400]	train's auc: 0.930619	train's f1: 0.844456	test's auc: 0.74522	test's f1: 0.680351
# Early stopping, best iteration is:
# [1358]	train's auc: 0.928045	train's f1: 0.8414	test's auc: 0.744255	test's f1: 0.681918
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.752693	train's f1: 0.680744	test's auc: 0.699767	test's f1: 0.645096
# [400]	train's auc: 0.803702	train's f1: 0.718959	test's auc: 0.713268	test's f1: 0.655986
# [600]	train's auc: 0.844845	train's f1: 0.755587	test's auc: 0.724282	test's f1: 0.661391
# [800]	train's auc: 0.875568	train's f1: 0.78444	test's auc: 0.7321	test's f1: 0.669226
# [1000]	train's auc: 0.897602	train's f1: 0.807514	test's auc: 0.737212	test's f1: 0.673535
# [1200]	train's auc: 0.915619	train's f1: 0.828139	test's auc: 0.741733	test's f1: 0.677139
# Early stopping, best iteration is:
# [1148]	train's auc: 0.910837	train's f1: 0.822733	test's auc: 0.740494	test's f1: 0.678549
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.750669	train's f1: 0.678276	test's auc: 0.708036	test's f1: 0.649248
# [400]	train's auc: 0.804092	train's f1: 0.717196	test's auc: 0.721488	test's f1: 0.660216
# [600]	train's auc: 0.846121	train's f1: 0.754353	test's auc: 0.731345	test's f1: 0.669226
# [800]	train's auc: 0.875663	train's f1: 0.783362	test's auc: 0.737428	test's f1: 0.674083
# [1000]	train's auc: 0.898897	train's f1: 0.807044	test's auc: 0.742895	test's f1: 0.679254
# [1200]	train's auc: 0.917772	train's f1: 0.829863	test's auc: 0.748063	test's f1: 0.681213
# [1400]	train's auc: 0.9315	train's f1: 0.847041	test's auc: 0.750618	test's f1: 0.68466
# [1600]	train's auc: 0.942607	train's f1: 0.861321	test's auc: 0.753754	test's f1: 0.687402
# Early stopping, best iteration is:
# [1615]	train's auc: 0.943255	train's f1: 0.862496	test's auc: 0.753976	test's f1: 0.688499
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.752917	train's f1: 0.683649	test's auc: 0.685661	test's f1: 0.634725
# [400]	train's auc: 0.80392	train's f1: 0.721021	test's auc: 0.699887	test's f1: 0.646321
# [600]	train's auc: 0.843825	train's f1: 0.755925	test's auc: 0.711077	test's f1: 0.656585
# [800]	train's auc: 0.874844	train's f1: 0.785051	test's auc: 0.719316	test's f1: 0.662775
# [1000]	train's auc: 0.898302	train's f1: 0.809966	test's auc: 0.72622	test's f1: 0.66873
# Early stopping, best iteration is:
# [1070]	train's auc: 0.905911	train's f1: 0.818193	test's auc: 0.727905	test's f1: 0.670767
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.750103	train's f1: 0.678993	test's auc: 0.699339	test's f1: 0.647469
# [400]	train's auc: 0.802664	train's f1: 0.718088	test's auc: 0.712795	test's f1: 0.658831
# [600]	train's auc: 0.844594	train's f1: 0.755029	test's auc: 0.724335	test's f1: 0.66557
# [800]	train's auc: 0.876075	train's f1: 0.784644	test's auc: 0.731317	test's f1: 0.672779
# [1000]	train's auc: 0.899569	train's f1: 0.808422	test's auc: 0.736457	test's f1: 0.674738
# Early stopping, best iteration is:
# [1025]	train's auc: 0.902066	train's f1: 0.810753	test's auc: 0.736971	test's f1: 0.676696
# 0.6707146998448689

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                categorical_feature=['设备类型','fake_id'],
                output_dir='gotcha_fakeid', name='lgb2',
                random_state=2019,
                n_folds=5, split_seed=2333,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=1,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=6)
train_prob = np.load('./gotcha_fakeid/val.lgb2.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb2.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.75226	train's f1: 0.682408	test's auc: 0.68791	test's f1: 0.636008
# [400]	train's auc: 0.803271	train's f1: 0.721074	test's auc: 0.702557	test's f1: 0.647603
# [600]	train's auc: 0.843426	train's f1: 0.756723	test's auc: 0.713281	test's f1: 0.654967
# [800]	train's auc: 0.875955	train's f1: 0.786575	test's auc: 0.722085	test's f1: 0.66241
# [1000]	train's auc: 0.899011	train's f1: 0.811725	test's auc: 0.728197	test's f1: 0.667346
# [1200]	train's auc: 0.917473	train's f1: 0.832272	test's auc: 0.733068	test's f1: 0.67189
# [1400]	train's auc: 0.931068	train's f1: 0.849039	test's auc: 0.737734	test's f1: 0.674632
# Early stopping, best iteration is:
# [1402]	train's auc: 0.931283	train's f1: 0.849666	test's auc: 0.737927	test's f1: 0.675572
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.748804	train's f1: 0.677845	test's auc: 0.698018	test's f1: 0.643999
# [400]	train's auc: 0.801297	train's f1: 0.716393	test's auc: 0.713265	test's f1: 0.655359
# [600]	train's auc: 0.843188	train's f1: 0.752257	test's auc: 0.724711	test's f1: 0.661156
# [800]	train's auc: 0.874566	train's f1: 0.783323	test's auc: 0.732808	test's f1: 0.668678
# [1000]	train's auc: 0.898395	train's f1: 0.808003	test's auc: 0.739343	test's f1: 0.672595
# [1200]	train's auc: 0.915691	train's f1: 0.826964	test's auc: 0.743992	test's f1: 0.67706
# [1400]	train's auc: 0.930275	train's f1: 0.845866	test's auc: 0.747842	test's f1: 0.680038
# [1600]	train's auc: 0.940926	train's f1: 0.859362	test's auc: 0.75119	test's f1: 0.68325
# [1800]	train's auc: 0.949333	train's f1: 0.871447	test's auc: 0.753927	test's f1: 0.68701
# [2000]	train's auc: 0.95554	train's f1: 0.881182	test's auc: 0.755588	test's f1: 0.687324
# Early stopping, best iteration is:
# [1917]	train's auc: 0.953112	train's f1: 0.87748	test's auc: 0.754868	test's f1: 0.688029
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.752148	train's f1: 0.68141	test's auc: 0.700432	test's f1: 0.64392
# [400]	train's auc: 0.802513	train's f1: 0.717568	test's auc: 0.712998	test's f1: 0.654575
# [600]	train's auc: 0.844332	train's f1: 0.754177	test's auc: 0.723422	test's f1: 0.66147
# [800]	train's auc: 0.875402	train's f1: 0.783637	test's auc: 0.731236	test's f1: 0.668129
# [1000]	train's auc: 0.900644	train's f1: 0.810609	test's auc: 0.737661	test's f1: 0.674867
# [1200]	train's auc: 0.918248	train's f1: 0.831215	test's auc: 0.742765	test's f1: 0.679019
# [1400]	train's auc: 0.931374	train's f1: 0.847159	test's auc: 0.746672	test's f1: 0.677374
# Early stopping, best iteration is:
# [1300]	train's auc: 0.925718	train's f1: 0.839676	test's auc: 0.744908	test's f1: 0.679959
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.748073	train's f1: 0.677538	test's auc: 0.701901	test's f1: 0.64828
# [400]	train's auc: 0.802909	train's f1: 0.718063	test's auc: 0.716636	test's f1: 0.658388
# [600]	train's auc: 0.842938	train's f1: 0.752341	test's auc: 0.725344	test's f1: 0.664577
# [800]	train's auc: 0.875271	train's f1: 0.784268	test's auc: 0.733369	test's f1: 0.667711
# [1000]	train's auc: 0.899327	train's f1: 0.809398	test's auc: 0.739221	test's f1: 0.673118
# [1200]	train's auc: 0.916671	train's f1: 0.828084	test's auc: 0.742844	test's f1: 0.67539
# [1400]	train's auc: 0.930296	train's f1: 0.845791	test's auc: 0.746092	test's f1: 0.680013
# Early stopping, best iteration is:
# [1411]	train's auc: 0.931204	train's f1: 0.84726	test's auc: 0.746124	test's f1: 0.681345
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.752078	train's f1: 0.682989	test's auc: 0.697496	test's f1: 0.643316
# [400]	train's auc: 0.803304	train's f1: 0.721026	test's auc: 0.709058	test's f1: 0.648018
# [600]	train's auc: 0.845658	train's f1: 0.754872	test's auc: 0.719522	test's f1: 0.655697
# [800]	train's auc: 0.876526	train's f1: 0.785584	test's auc: 0.727499	test's f1: 0.663062
# [1000]	train's auc: 0.900264	train's f1: 0.81044	test's auc: 0.734206	test's f1: 0.671133
# [1200]	train's auc: 0.917701	train's f1: 0.829889	test's auc: 0.738377	test's f1: 0.674659
# [1400]	train's auc: 0.931553	train's f1: 0.849202	test's auc: 0.742326	test's f1: 0.677558
# [1600]	train's auc: 0.941882	train's f1: 0.861365	test's auc: 0.745685	test's f1: 0.681633
# Early stopping, best iteration is:
# [1630]	train's auc: 0.942991	train's f1: 0.862991	test's auc: 0.746041	test's f1: 0.682495
# 0.6734725856746635

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                categorical_feature=['设备类型','fake_id'],
                output_dir='gotcha_fakeid', name='lgb3',
                random_state=2012,
                n_folds=5, split_seed=1111,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=1,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=6)
train_prob = np.load('./gotcha_fakeid/val.lgb3.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb3.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.750928	train's f1: 0.680489	test's auc: 0.698283	test's f1: 0.642589
# [400]	train's auc: 0.801752	train's f1: 0.716452	test's auc: 0.711947	test's f1: 0.654027
# [600]	train's auc: 0.843447	train's f1: 0.752022	test's auc: 0.722197	test's f1: 0.661235
# [800]	train's auc: 0.874091	train's f1: 0.781462	test's auc: 0.730078	test's f1: 0.669069
# [1000]	train's auc: 0.897998	train's f1: 0.806221	test's auc: 0.737136	test's f1: 0.674005
# [1200]	train's auc: 0.916867	train's f1: 0.828551	test's auc: 0.742358	test's f1: 0.680116
# [1400]	train's auc: 0.931441	train's f1: 0.845827	test's auc: 0.746646	test's f1: 0.685208
# Early stopping, best iteration is:
# [1448]	train's auc: 0.934179	train's f1: 0.849568	test's auc: 0.747328	test's f1: 0.686932
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.751451	train's f1: 0.679882	test's auc: 0.695459	test's f1: 0.644469
# [400]	train's auc: 0.805407	train's f1: 0.720154	test's auc: 0.71229	test's f1: 0.657396
# [600]	train's auc: 0.845912	train's f1: 0.756253	test's auc: 0.72311	test's f1: 0.664212
# [800]	train's auc: 0.877257	train's f1: 0.78775	test's auc: 0.731751	test's f1: 0.670558
# [1000]	train's auc: 0.899962	train's f1: 0.810001	test's auc: 0.738816	test's f1: 0.676512
# [1200]	train's auc: 0.917808	train's f1: 0.831019	test's auc: 0.743728	test's f1: 0.679097
# [1400]	train's auc: 0.932031	train's f1: 0.849078	test's auc: 0.747981	test's f1: 0.681526
# [1600]	train's auc: 0.942566	train's f1: 0.864278	test's auc: 0.751662	test's f1: 0.685208
# Early stopping, best iteration is:
# [1614]	train's auc: 0.943152	train's f1: 0.865258	test's auc: 0.751828	test's f1: 0.687794
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.751774	train's f1: 0.678687	test's auc: 0.692285	test's f1: 0.635302
# [400]	train's auc: 0.803826	train's f1: 0.717823	test's auc: 0.708353	test's f1: 0.646819
# [600]	train's auc: 0.844677	train's f1: 0.754725	test's auc: 0.719786	test's f1: 0.655202
# [800]	train's auc: 0.875494	train's f1: 0.784381	test's auc: 0.727216	test's f1: 0.659903
# [1000]	train's auc: 0.898554	train's f1: 0.808238	test's auc: 0.7329	test's f1: 0.664134
# [1200]	train's auc: 0.915855	train's f1: 0.828433	test's auc: 0.738069	test's f1: 0.668913
# [1400]	train's auc: 0.93002	train's f1: 0.845435	test's auc: 0.742242	test's f1: 0.673848
# [1600]	train's auc: 0.941599	train's f1: 0.860145	test's auc: 0.745774	test's f1: 0.67565
# [1800]	train's auc: 0.949836	train's f1: 0.871761	test's auc: 0.748307	test's f1: 0.677452
# Early stopping, best iteration is:
# [1710]	train's auc: 0.946286	train's f1: 0.866217	test's auc: 0.746946	test's f1: 0.677922
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.751699	train's f1: 0.682043	test's auc: 0.697532	test's f1: 0.642012
# [400]	train's auc: 0.805263	train's f1: 0.721099	test's auc: 0.712187	test's f1: 0.653608
# [600]	train's auc: 0.845487	train's f1: 0.755279	test's auc: 0.723712	test's f1: 0.659955
# [800]	train's auc: 0.875176	train's f1: 0.782897	test's auc: 0.731376	test's f1: 0.664342
# [1000]	train's auc: 0.897221	train's f1: 0.805657	test's auc: 0.736126	test's f1: 0.66873
# [1200]	train's auc: 0.91612	train's f1: 0.827065	test's auc: 0.740607	test's f1: 0.674136
# Early stopping, best iteration is:
# [1209]	train's auc: 0.916963	train's f1: 0.827966	test's auc: 0.740926	test's f1: 0.675547
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.748323	train's f1: 0.676839	test's auc: 0.702524	test's f1: 0.646607
# [400]	train's auc: 0.801554	train's f1: 0.717285	test's auc: 0.716784	test's f1: 0.659693
# [600]	train's auc: 0.842563	train's f1: 0.752443	test's auc: 0.726316	test's f1: 0.669252
# [800]	train's auc: 0.873187	train's f1: 0.782117	test's auc: 0.733672	test's f1: 0.674738
# [1000]	train's auc: 0.896866	train's f1: 0.805915	test's auc: 0.739106	test's f1: 0.678264
# [1200]	train's auc: 0.915539	train's f1: 0.825835	test's auc: 0.742921	test's f1: 0.680693
# [1400]	train's auc: 0.929602	train's f1: 0.844325	test's auc: 0.747322	test's f1: 0.68367
# [1600]	train's auc: 0.940896	train's f1: 0.859348	test's auc: 0.750359	test's f1: 0.687196
# [1800]	train's auc: 0.949463	train's f1: 0.871589	test's auc: 0.752941	test's f1: 0.68892
# Early stopping, best iteration is:
# [1733]	train's auc: 0.946843	train's f1: 0.867907	test's auc: 0.752039	test's f1: 0.690017
# 0.6751335850948806

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                output_dir='gotcha_fakeid', name='lgb4',
                categorical_feature=['设备类型','fake_id'],
                random_state=5678,
                min_child_samples=50,
                n_folds=5, split_seed=4321,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=0.9,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=4)
train_prob = np.load('./gotcha_fakeid/val.lgb4.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb4.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.696701	train's f1: 0.638768	test's auc: 0.672726	test's f1: 0.625823
# [400]	train's auc: 0.720989	train's f1: 0.656592	test's auc: 0.681679	test's f1: 0.628408
# [600]	train's auc: 0.7414	train's f1: 0.67046	test's auc: 0.689506	test's f1: 0.634989
# [800]	train's auc: 0.758238	train's f1: 0.683525	test's auc: 0.694793	test's f1: 0.639533
# [1000]	train's auc: 0.773282	train's f1: 0.695983	test's auc: 0.698667	test's f1: 0.64345
# [1200]	train's auc: 0.787599	train's f1: 0.707167	test's auc: 0.703294	test's f1: 0.646819
# [1400]	train's auc: 0.799778	train's f1: 0.718724	test's auc: 0.706811	test's f1: 0.64917
# [1600]	train's auc: 0.811142	train's f1: 0.729046	test's auc: 0.709801	test's f1: 0.653479
# [1800]	train's auc: 0.821237	train's f1: 0.737626	test's auc: 0.712633	test's f1: 0.655202
# Early stopping, best iteration is:
# [1709]	train's auc: 0.816409	train's f1: 0.733571	test's auc: 0.711333	test's f1: 0.655907
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.695816	train's f1: 0.637671	test's auc: 0.670571	test's f1: 0.62026
# [400]	train's auc: 0.720345	train's f1: 0.65622	test's auc: 0.680296	test's f1: 0.628878
# [600]	train's auc: 0.740802	train's f1: 0.67046	test's auc: 0.687886	test's f1: 0.633344
# [800]	train's auc: 0.75803	train's f1: 0.682957	test's auc: 0.692487	test's f1: 0.63922
# [1000]	train's auc: 0.772872	train's f1: 0.694827	test's auc: 0.697277	test's f1: 0.642745
# [1200]	train's auc: 0.787348	train's f1: 0.705835	test's auc: 0.701667	test's f1: 0.646114
# [1400]	train's auc: 0.800081	train's f1: 0.717137	test's auc: 0.704609	test's f1: 0.647368
# [1600]	train's auc: 0.81179	train's f1: 0.727832	test's auc: 0.707886	test's f1: 0.65246
# Early stopping, best iteration is:
# [1584]	train's auc: 0.810968	train's f1: 0.7265	test's auc: 0.707913	test's f1: 0.653087
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.69353	train's f1: 0.635144	test's auc: 0.670711	test's f1: 0.6212
# [400]	train's auc: 0.718699	train's f1: 0.654026	test's auc: 0.682336	test's f1: 0.632012
# [600]	train's auc: 0.738724	train's f1: 0.669383	test's auc: 0.68899	test's f1: 0.635381
# [800]	train's auc: 0.756371	train's f1: 0.682056	test's auc: 0.694946	test's f1: 0.641413
# Early stopping, best iteration is:
# [811]	train's auc: 0.757199	train's f1: 0.682839	test's auc: 0.695201	test's f1: 0.641492
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.693644	train's f1: 0.634818	test's auc: 0.677484	test's f1: 0.627674
# [400]	train's auc: 0.716312	train's f1: 0.652446	test's auc: 0.686916	test's f1: 0.634569
# [600]	train's auc: 0.737139	train's f1: 0.666921	test's auc: 0.694514	test's f1: 0.640132
# [800]	train's auc: 0.754965	train's f1: 0.681416	test's auc: 0.700358	test's f1: 0.646713
# [1000]	train's auc: 0.770481	train's f1: 0.692659	test's auc: 0.705656	test's f1: 0.649926
# [1200]	train's auc: 0.784607	train's f1: 0.705038	test's auc: 0.709816	test's f1: 0.651963
# Early stopping, best iteration is:
# [1103]	train's auc: 0.778124	train's f1: 0.69877	test's auc: 0.7077	test's f1: 0.652119
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.693765	train's f1: 0.635374	test's auc: 0.677251	test's f1: 0.623962
# [400]	train's auc: 0.718553	train's f1: 0.653726	test's auc: 0.687765	test's f1: 0.633992
# [600]	train's auc: 0.738258	train's f1: 0.666771	test's auc: 0.695587	test's f1: 0.640025
# [800]	train's auc: 0.755693	train's f1: 0.679307	test's auc: 0.701432	test's f1: 0.645197
# [1000]	train's auc: 0.770914	train's f1: 0.692077	test's auc: 0.705854	test's f1: 0.64982
# [1200]	train's auc: 0.7848	train's f1: 0.702967	test's auc: 0.709485	test's f1: 0.654129
# [1400]	train's auc: 0.797164	train's f1: 0.713995	test's auc: 0.712967	test's f1: 0.65742
# [1600]	train's auc: 0.809059	train's f1: 0.722946	test's auc: 0.716388	test's f1: 0.658596
# [1800]	train's auc: 0.81895	train's f1: 0.732445	test's auc: 0.718835	test's f1: 0.660555
# [2000]	train's auc: 0.828071	train's f1: 0.74077	test's auc: 0.721252	test's f1: 0.664159
# Early stopping, best iteration is:
# [2041]	train's auc: 0.830122	train's f1: 0.742121	test's auc: 0.721768	test's f1: 0.664864
# 0.6429007944591566

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                output_dir='gotcha_fakeid', name='lgb5',
                categorical_feature=['设备类型','fake_id'],
                random_state=987,
                min_child_samples=50,
                n_folds=5, split_seed=789,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=0.9,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=4)
train_prob = np.load('./gotcha_fakeid/val.lgb5.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb5.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.695616	train's f1: 0.637592	test's auc: 0.667386	test's f1: 0.618145
# [400]	train's auc: 0.718941	train's f1: 0.654535	test's auc: 0.676996	test's f1: 0.622924
# [600]	train's auc: 0.740035	train's f1: 0.669167	test's auc: 0.685518	test's f1: 0.629818
# [800]	train's auc: 0.757328	train's f1: 0.682506	test's auc: 0.691713	test's f1: 0.635616
# [1000]	train's auc: 0.773162	train's f1: 0.694318	test's auc: 0.697493	test's f1: 0.639533
# [1200]	train's auc: 0.78688	train's f1: 0.705796	test's auc: 0.701658	test's f1: 0.643685
# [1400]	train's auc: 0.799037	train's f1: 0.715727	test's auc: 0.704554	test's f1: 0.645722
# [1600]	train's auc: 0.810383	train's f1: 0.725658	test's auc: 0.708231	test's f1: 0.648778
# [1800]	train's auc: 0.820427	train's f1: 0.734217	test's auc: 0.710638	test's f1: 0.651207
# [2000]	train's auc: 0.830299	train's f1: 0.743326	test's auc: 0.713669	test's f1: 0.653322
# [2200]	train's auc: 0.838903	train's f1: 0.751004	test's auc: 0.716247	test's f1: 0.656064
# Early stopping, best iteration is:
# [2232]	train's auc: 0.840503	train's f1: 0.752806	test's auc: 0.71671	test's f1: 0.656691
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.693078	train's f1: 0.634693	test's auc: 0.676863	test's f1: 0.627076
# [400]	train's auc: 0.718384	train's f1: 0.653693	test's auc: 0.687633	test's f1: 0.634362
# [600]	train's auc: 0.739213	train's f1: 0.669696	test's auc: 0.69457	test's f1: 0.641492
# [800]	train's auc: 0.757817	train's f1: 0.682683	test's auc: 0.700692	test's f1: 0.646976
# [1000]	train's auc: 0.773241	train's f1: 0.694749	test's auc: 0.704401	test's f1: 0.648778
# [1200]	train's auc: 0.787575	train's f1: 0.70656	test's auc: 0.708357	test's f1: 0.65058
# [1400]	train's auc: 0.799484	train's f1: 0.715903	test's auc: 0.711004	test's f1: 0.65199
# Early stopping, best iteration is:
# [1366]	train's auc: 0.797716	train's f1: 0.714963	test's auc: 0.710696	test's f1: 0.654027
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.693416	train's f1: 0.633753	test's auc: 0.674841	test's f1: 0.623707
# [400]	train's auc: 0.719055	train's f1: 0.655221	test's auc: 0.685153	test's f1: 0.630993
# [600]	train's auc: 0.738465	train's f1: 0.669089	test's auc: 0.691362	test's f1: 0.635772
# [800]	train's auc: 0.755741	train's f1: 0.68139	test's auc: 0.697376	test's f1: 0.638828
# [1000]	train's auc: 0.771374	train's f1: 0.69279	test's auc: 0.702572	test's f1: 0.642667
# [1200]	train's auc: 0.784633	train's f1: 0.702995	test's auc: 0.706377	test's f1: 0.645957
# [1400]	train's auc: 0.796755	train's f1: 0.71318	test's auc: 0.709608	test's f1: 0.650658
# Early stopping, best iteration is:
# [1396]	train's auc: 0.796624	train's f1: 0.713318	test's auc: 0.709546	test's f1: 0.650736
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.694555	train's f1: 0.635327	test's auc: 0.675157	test's f1: 0.62736
# [400]	train's auc: 0.719544	train's f1: 0.654601	test's auc: 0.684989	test's f1: 0.633158
# [600]	train's auc: 0.739787	train's f1: 0.668919	test's auc: 0.692312	test's f1: 0.637468
# [800]	train's auc: 0.757661	train's f1: 0.681239	test's auc: 0.698463	test's f1: 0.642639
# [1000]	train's auc: 0.773449	train's f1: 0.693775	test's auc: 0.703622	test's f1: 0.649064
# [1200]	train's auc: 0.787251	train's f1: 0.704705	test's auc: 0.70743	test's f1: 0.653373
# [1400]	train's auc: 0.799506	train's f1: 0.714205	test's auc: 0.710638	test's f1: 0.65447
# [1600]	train's auc: 0.810308	train's f1: 0.723783	test's auc: 0.713449	test's f1: 0.657056
# Early stopping, best iteration is:
# [1598]	train's auc: 0.810225	train's f1: 0.723822	test's auc: 0.713436	test's f1: 0.657212
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.693588	train's f1: 0.636137	test's auc: 0.674159	test's f1: 0.625607
# [400]	train's auc: 0.718298	train's f1: 0.654157	test's auc: 0.683759	test's f1: 0.632816
# [600]	train's auc: 0.738875	train's f1: 0.66871	test's auc: 0.690812	test's f1: 0.637047
# [800]	train's auc: 0.756086	train's f1: 0.68058	test's auc: 0.696207	test's f1: 0.640103
# [1000]	train's auc: 0.77181	train's f1: 0.69386	test's auc: 0.700954	test's f1: 0.643551
# [1200]	train's auc: 0.785425	train's f1: 0.705083	test's auc: 0.705008	test's f1: 0.64935
# [1400]	train's auc: 0.797796	train's f1: 0.714249	test's auc: 0.708547	test's f1: 0.650447
# Early stopping, best iteration is:
# [1421]	train's auc: 0.798877	train's f1: 0.715679	test's auc: 0.709088	test's f1: 0.651465
# 0.645313944560227

# %%
model = kf_lgbm(x=train_feat_df[feature_name1], y=train_feat_df.label.values, 
                x_test=test_feat_df[feature_name1], 
                output_dir='gotcha_fakeid', name='lgb6',
                categorical_feature=['设备类型','fake_id'],
                random_state=2015,
                min_child_samples=50,
                n_folds=5, split_seed=2012,
                learning_rate=0.03,
                colsample_bytree=0.5,
                early_stopping_rounds=100,
                num_leaves=64, 
                min_split_gain=0.9,
                n_estimators=5000,
                eval_metric=metric_micro_f1,
                max_depth=4)
train_prob = np.load('./gotcha_fakeid/val.lgb6.npy')
test_prob = np.load('./gotcha_fakeid/test.lgb6.npy')
print(f1_score(train_feat_df.label.values,train_prob>0.46,average='micro'))
# Out:
# ========================= Fold 1 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.695841	train's f1: 0.638023	test's auc: 0.670376	test's f1: 0.620887
# [400]	train's auc: 0.720461	train's f1: 0.656651	test's auc: 0.680185	test's f1: 0.630132
# [600]	train's auc: 0.740712	train's f1: 0.670127	test's auc: 0.687699	test's f1: 0.637496
# [800]	train's auc: 0.757727	train's f1: 0.683153	test's auc: 0.69337	test's f1: 0.637888
# [1000]	train's auc: 0.772758	train's f1: 0.694024	test's auc: 0.698665	test's f1: 0.644782
# [1200]	train's auc: 0.786319	train's f1: 0.704542	test's auc: 0.702957	test's f1: 0.647446
# Early stopping, best iteration is:
# [1275]	train's auc: 0.791142	train's f1: 0.708871	test's auc: 0.704329	test's f1: 0.650266
#
# ========================= Fold 2 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.694977	train's f1: 0.63675	test's auc: 0.676891	test's f1: 0.625979
# [400]	train's auc: 0.719302	train's f1: 0.653282	test's auc: 0.686343	test's f1: 0.632012
# [600]	train's auc: 0.740422	train's f1: 0.669833	test's auc: 0.694148	test's f1: 0.638045
# [800]	train's auc: 0.757868	train's f1: 0.683172	test's auc: 0.699882	test's f1: 0.645174
# [1000]	train's auc: 0.772988	train's f1: 0.694788	test's auc: 0.704146	test's f1: 0.647289
# Early stopping, best iteration is:
# [959]	train's auc: 0.769901	train's f1: 0.692809	test's auc: 0.703689	test's f1: 0.648229
#
# ========================= Fold 3 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.695132	train's f1: 0.636358	test's auc: 0.669429	test's f1: 0.623786
# [400]	train's auc: 0.720234	train's f1: 0.654144	test's auc: 0.680822	test's f1: 0.63162
# [600]	train's auc: 0.740251	train's f1: 0.668678	test's auc: 0.687726	test's f1: 0.636478
# [800]	train's auc: 0.757562	train's f1: 0.682154	test's auc: 0.693112	test's f1: 0.640708
# [1000]	train's auc: 0.772691	train's f1: 0.694925	test's auc: 0.697529	test's f1: 0.644939
# Early stopping, best iteration is:
# [1027]	train's auc: 0.774833	train's f1: 0.696805	test's auc: 0.698346	test's f1: 0.646741
#
# ========================= Fold 4 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.69454	train's f1: 0.63709	test's auc: 0.676789	test's f1: 0.626028
# [400]	train's auc: 0.718869	train's f1: 0.653876	test's auc: 0.685304	test's f1: 0.632688
# [600]	train's auc: 0.738971	train's f1: 0.668743	test's auc: 0.692288	test's f1: 0.636214
# [800]	train's auc: 0.75651	train's f1: 0.681651	test's auc: 0.697137	test's f1: 0.641934
# [1000]	train's auc: 0.772297	train's f1: 0.694755	test's auc: 0.701585	test's f1: 0.645538
# [1200]	train's auc: 0.786171	train's f1: 0.705351	test's auc: 0.705235	test's f1: 0.647027
# Early stopping, best iteration is:
# [1112]	train's auc: 0.780279	train's f1: 0.700337	test's auc: 0.703328	test's f1: 0.648045
#
# ========================= Fold 5 =========================
# Training until validation scores don't improve for 100 rounds.
# [200]	train's auc: 0.694793	train's f1: 0.637371	test's auc: 0.674151	test's f1: 0.622708
# [400]	train's auc: 0.719368	train's f1: 0.655705	test's auc: 0.684307	test's f1: 0.632268
# [600]	train's auc: 0.738847	train's f1: 0.668495	test's auc: 0.691057	test's f1: 0.636107
# [800]	train's auc: 0.756709	train's f1: 0.681344	test's auc: 0.697185	test's f1: 0.641749
# [1000]	train's auc: 0.772541	train's f1: 0.694251	test's auc: 0.702511	test's f1: 0.645353
# Early stopping, best iteration is:
# [1050]	train's auc: 0.776206	train's f1: 0.696504	test's auc: 0.703673	test's f1: 0.647626
# 0.6397668332889356
